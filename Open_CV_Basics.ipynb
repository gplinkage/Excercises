# %% [markdown]
# <a href="https://colab.research.google.com/github/gplinkage/Excercises/blob/main/Open_CV_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf

from google.colab.patches import cv2_imshow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D

# %%
img= cv2.imread('fruit_example.jpg')

# %%
img
# Out:
# array([[[120,  30, 103],
#         [120,  30, 103],
#         [120,  30, 103],
#         ...,
#         [176,  64, 195],
#         [174,  65, 193],
#         [174,  65, 193]],
#
#        [[120,  30, 103],
#         [120,  30, 103],
#         [120,  30, 103],
#         ...,
#         [175,  64, 192],
#         [173,  64, 192],
#         [173,  64, 192]],
#
#        [[120,  30, 103],
#         [120,  30, 103],
#         [120,  30, 103],
#         ...,
#         [174,  63, 191],
#         [174,  63, 191],
#         [174,  63, 191]],
#
#        ...,
#
#        [[140,  18, 124],
#         [140,  18, 124],
#         [140,  18, 126],
#         ...,
#         [180,  27, 184],
#         [178,  27, 184],
#         [180,  27, 184]],
#
#        [[140,  18, 124],
#         [140,  18, 124],
#         [140,  18, 126],
#         ...,
#         [178,  27, 184],
#         [176,  27, 184],
#         [178,  27, 184]],
#
#        [[140,  18, 124],
#         [140,  18, 124],
#         [140,  18, 126],
# ...

# %%
cv2.imread('fruit_example.jpg', 0)
# Out:
# array([[ 62,  62,  62, ..., 116, 116, 116],
#        [ 62,  62,  62, ..., 115, 115, 115],
#        [ 62,  62,  62, ..., 114, 114, 114],
#        ...,
#        [ 64,  64,  64, ...,  91,  91,  91],
#        [ 64,  64,  64, ...,  91,  91,  91],
#        [ 64,  64,  64, ...,  91,  91,  91]], dtype=uint8)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img3 = img.copy()

# %%
img2= cv2.imread('fruit_example.jpg', 0)
cv2.imwrite('fruit_example_gray.jpg', img2)
# Out:
# True

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
B, G, R = cv2.split(img)

# %%
cv2_imshow(B)
cv2_imshow(G)
cv2_imshow(R)
# Out:
# <PIL.Image.Image image mode=L size=275x183>
# <PIL.Image.Image image mode=L size=275x183>
# <PIL.Image.Image image mode=L size=275x183>

# %%
weightedsum = cv2.addWeighted(img, 0.1, img3, 0.5, 0)
cv2_imshow(weightedsum)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
img4= cv2.imread('download.jpeg')
cv2_imshow(img4)
# Out:
# <PIL.Image.Image image mode=RGB size=276x183>

# %%
img4.shape
# Out:
# (183, 276, 3)

# %%
img4.size
# Out:
# 151524

# %%
karnel = np.ones((3, 3), np.float32)/25
image_erode = cv2.erode(img4, karnel)
cv2_imshow(image_erode)
# Out:
# <PIL.Image.Image image mode=RGB size=276x183>
